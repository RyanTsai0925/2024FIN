# %% [markdown]
# <a href="https://colab.research.google.com/github/RyanTsai0925/2024FIN/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fredapi

# %%
from fredapi import Fred


fred = Fred(api_key='acf2e3d57107d17b88aa9b9b6ea8fff9')


data1 = fred.get_series('MICH')


data1 = fred.get_series('MICH', '6/1/2021')


data1.plot()
# Out:
# <Axes: >

# %%
data2 = fred.get_series('UNRATE')


data2 = fred.get_series('UNRATE', '6/1/2021')


data1.plot()
data2.plot()
# Out:
# <Axes: >
